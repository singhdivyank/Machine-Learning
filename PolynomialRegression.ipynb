# %% [markdown]
# Implementing **Polynomial Liner Regression** on position slaraies and us.csv dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# # Position_salaries

# %%
dataset = pd.read_csv(r'E:\Jupyterfiles\ML_practice\Position_Salaries.csv')
dataset.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
dataset.tail()
# Out:
#          Position  Level   Salary
# 5  Region Manager      6   150000
# 6         Partner      7   200000
# 7  Senior Partner      8   300000
# 8         C-level      9   500000
# 9             CEO     10  1000000

# %%
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### Making prediction at 6.5 using Linear Regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# **Visualising the Polynomial Regression results (for higher resolution and smoother curve)**

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### Making prediction at 6.5

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265153])

# %% [markdown]
# # us.csv

# %%
data = pd.read_csv(r'E:\Jupyterfiles\ML_practice\us.csv')
data.head()
# Out:
#    Day  cases  deaths
# 0    1      1       0
# 1    2      1       0
# 2    3      1       0
# 3    4      2       0
# 4    5      3       0

# %%
data.tail()
# Out:
#      Day    cases  deaths
# 207  208  5372971  169395
# 208  209  5415114  169909
# 209  210  5455136  170451
# 210  211  5498362  171800
# 211  212  5541294  173094

# %% [markdown]
# ## According to cases and death

# %%
X = data.iloc[:, 1:-1].values
Y = data.iloc[:, -1].values

# %% [markdown]
# ### Linear Regression

# %%
l_regression = LinearRegression()
l_regression.fit(X, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, l_regression.predict(X), color = 'blue')
plt.title('Linear Regression')
plt.xlabel('Daily Cases')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# ### Making prediction at 6.5

# %%
l_regression.predict([[6.5]])
# Out:
# array([13003.93990334])

# %% [markdown]
# ### Polynomial Regression
# * Attempt 1 - Degree 5
# * Attempt 2 - Degree 4
# * Attempt 3 - Degree 3
# * Attempt 4 - Degree 2
#
# **Attempt 1:**

# %%
p_regression = PolynomialFeatures(degree = 5)
X_p5 = p_regression.fit_transform(X)
l_reg_5 = LinearRegression()
l_reg_5.fit(X_p5, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, l_reg_5.predict(X_p5), color = 'blue')
plt.title('Degree 5 Polynomial Regression')
plt.xlabel('Daily Cases')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# **Attempt 2:**

# %%
p_regression = PolynomialFeatures(degree = 4)
X_p4 = p_regression.fit_transform(X)
l_reg_4 = LinearRegression()
l_reg_4.fit(X_p4, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, l_reg_4.predict(X_p4), color = 'blue')
plt.title('Degree 4 Polynomial Regression')
plt.xlabel('Daily Cases')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# **Attempt 3:**

# %%
p_regression3 = PolynomialFeatures(degree = 3)
X_p3 = p_regression3.fit_transform(X)
l_reg_3 = LinearRegression()
l_reg_3.fit(X_p3, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, l_reg_3.predict(X_p3), color = 'blue')
plt.title('Degree 3 Polynomial Regression')
plt.xlabel('Daily Cases')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# **Attempt 4:**

# %%
p_regression2 = PolynomialFeatures(degree = 2)
X_p2 = p_regression2.fit_transform(X)
l_reg_2 = LinearRegression()
l_reg_2.fit(X_p2, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, l_reg_2.predict(X_p2), color = 'blue')
plt.title('Degree 2 Polynomial Regression')
plt.xlabel('Daily Cases')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# ### Making prediction at 6.5

# %%
l_reg_3.predict(p_regression3.fit_transform([[6.5]]))
# Out:
# array([-2990.24444102])

# %% [markdown]
# ## According to days and death

# %%
X = data.iloc[:, 0:1].values
Y = data.iloc[:, -1].values

# %% [markdown]
# ### Linear Regression

# %%
l_regression = LinearRegression()
l_regression.fit(X, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, l_regression.predict(X), color = 'blue')
plt.title('Linear Regression')
plt.xlabel('Daily Cases')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# ### prediction at 6.5

# %%
l_regression.predict([[6.5]])
# Out:
# array([-28194.64113317])

# %% [markdown]
# ### Polynomial Regression
#
# * Attempt 1 - Degree 10
# * Attempt 2 - Degree 9
# * Attempt 3 - Degree 8
# * Attempt 4 - Degree 4
# * Attempt 5 - Degree 3
# * Attempt 6 - Degree 2
#
# **Attempt 1:**

# %%
p_regression1 = PolynomialFeatures(degree = 10)
X_p10 = p_regression1.fit_transform(X)
l_reg_10 = LinearRegression()
l_reg_10.fit(X_p10, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, l_reg_10.predict(X_p10), color = 'blue')
plt.title('Degree 10 Polynomial Regression')
plt.xlabel('Days')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# **Attempt 2:**

# %%
p_regression2 = PolynomialFeatures(degree = 9)
X_p9 = p_regression2.fit_transform(X)
l_reg_9 = LinearRegression()
l_reg_9.fit(X_p9, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, l_reg_9.predict(X_p9), color = 'blue')
plt.title('Degree 9 Polynomial Regression')
plt.xlabel('Days')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# **Attempt 3:**

# %%
p_regression3 = PolynomialFeatures(degree = 8)
X_p8 = p_regression3.fit_transform(X)
l_reg_8 = LinearRegression()
l_reg_8.fit(X_p8, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, l_reg_8.predict(X_p8), color = 'blue')
plt.title('Degree 8 Polynomial Regression')
plt.xlabel('Days')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# **Attempt 4:**

# %%
p_regression4 = PolynomialFeatures(degree = 4)
X_p4 = p_regression4.fit_transform(X)
l_reg_4 = LinearRegression()
l_reg_4.fit(X_p4, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, l_reg_4.predict(X_p4), color = 'blue')
plt.title('Degree 4 Polynomial Regression')
plt.xlabel('Days')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# **Attempt 5:**

# %%
p_regression5 = PolynomialFeatures(degree = 3)
X_p3 = p_regression5.fit_transform(X)
l_reg_3 = LinearRegression()
l_reg_3.fit(X_p3, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, l_reg_3.predict(X_p3), color = 'blue')
plt.title('Degree 3 Polynomial Regression')
plt.xlabel('Days')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# **Attempt 6:**

# %%
p_regression6 = PolynomialFeatures(degree = 2)
X_p2 = p_regression6.fit_transform(X)
l_reg_2 = LinearRegression()
l_reg_2.fit(X_p2, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'red')
plt.plot(X, l_reg_2.predict(X_p2), color = 'blue')
plt.title('Degree 2 Polynomial Regression')
plt.xlabel('Days')
plt.ylabel('Deaths')
plt.show()

# %% [markdown]
# ### prediction at 6.5

# %%
l_reg_3.predict(p_regression5.fit_transform([[6.5]]))
# Out:
# array([1726.20898022])

# %% [markdown]
# # Conclusion
# 1. According to days and death
#
# Best Fit - Degree 9
#
# **Fit worsens as degree reduces**
#
# 2. According to daily cases and death
#
# Best fit - Degree 3
#
# **Fit worsens as degree increases**
